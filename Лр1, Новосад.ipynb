# %% [markdown]
# ##Новосад Тетяна Миколаївна
# Група 2-8,
# Лабораторна робата №1,
# Варіан 19

# %% [markdown]
# Завдання 1:
# корінь з 12 = 3,46; 19/12 = 1,58

# %%
import numpy as np

x1 = np.sqrt(12)
x2 = 19/12
x11 = 3.46
x22 = 1.58

b1 = f(x1, x11)
b2 = f(x2, x22)

print("Відносна похиюка першого приклада: ", b1)
print("Відносна похибка другога приклада: ", b2)

if b1 < b2:
  print('Це значає, що корінь з 12 = 3,46 більш точне оскільки його похибка менша і дорівнює')
  print(round(b1, 5))
else:
  print("Це значає, що 19/12 = 1,58 більш точне оскільки його похибка менша і дорівнює")
  print(round(b2, 5))
# Out:
# Відносна похиюка першого приклада:  0.0011840343019473797
# Відносна похибка другога приклада:  0.0021052631578946453
# Це значає, що корінь з 12 = 3,46 більш точне оскільки його похибка менша і дорівнює
# 0.00118

# %% [markdown]
# ![photo_2_2024-08-06_16-39-42.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![photo_1_2024-08-06_16-39-42.jpg](data:image/jpeg;base64,...)
